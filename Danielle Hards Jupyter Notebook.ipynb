# %% [markdown]
# <h1>My Jupyter Notebook on IBM Watson Studio<h1>

# %% [markdown]
# <b>Danielle Hards </b> <br>
# I am a government analyst

# %% [markdown]
# <i>I am interested in data science because I am typically involved in the analysis of curated data and in the explanation of findings to clients, but I am interested in learning to ingest and curate bulk data from big data applications. This will expand my marketability. </i>

# %% [markdown]
# <h3> This code should say hello, ask you for your name, and then say nice to meet you<h3>

# %%
print("Hello, classmate! What is your name?")
classmatename=input()
print("Lovely to meet you, "+classmatename)
# Out:
# Hello, classmate! What is your name?
# Danielle
# Lovely to meet you, Danielle

# %% [markdown]
# ---
# - your
# - friend
# - danielle <br>
# <a> href="https://www.trssllc.com/" >Link to My Company's website</a>
